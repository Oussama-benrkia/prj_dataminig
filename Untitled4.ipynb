# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, recall_score, roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
target_distribution = df['target'].value_counts(normalize=True) * 100
print("Target variable distribution (%):\n", target_distribution)
# Out:
# Target variable distribution (%):
#  target
# 1    51.317073
# 0    48.682927
# Name: proportion, dtype: float64

# %%
X, y = df.drop('target', axis=1), df['target']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier()
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
svc = SVC()
svc.fit(X_train_scaled, y_train)
# Out:
# SVC()

# %%
models = {
    "KNN": knn,
    "Logistic Regression": logistic_regression,
    "SVC": svc
}

for name, model in models.items():
    y_pred = model.predict(X_test_scaled if name in ["KNN", "Logistic Regression", "SVC"] else X_test)
    print(f"{name} Classification Report:")
    print(classification_report(y_test, y_pred))
    print("-" * 55)
# Out:
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       150
#            1       0.89      0.85      0.87       158
#
#     accuracy                           0.87       308
#    macro avg       0.87      0.87      0.87       308
# weighted avg       0.87      0.87      0.87       308
#
# -------------------------------------------------------
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80       150
#            1       0.78      0.89      0.83       158
#
#     accuracy                           0.82       308
#    macro avg       0.83      0.82      0.82       308
# weighted avg       0.82      0.82      0.82       308
#
# -------------------------------------------------------
# SVC Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       150
#            1       0.91      0.91      0.91       158
#
#     accuracy                           0.91       308
#    macro avg       0.91      0.91      0.91       308
# weighted avg       0.91      0.91      0.91       308
#
# -------------------------------------------------------

# %%
def evaluate_model_performance(models, X_test, X_test_scaled, y_test):
    for name, model in models.items():
        y_pred = model.predict(X_test_scaled if name in ["KNN", "Logistic Regression", "SVC"] else X_test)
        print(f"Model: {name}")
        print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
        print(f"Precision: {precision_score(y_test, y_pred):.2f}")
        print(f"Recall: {recall_score(y_test, y_pred):.2f}")
        print(f"F1 Score: {f1_score(y_test, y_pred):.2f}")
        print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
        print("-" * 25)

evaluate_model_performance(models, X_test, X_test_scaled, y_test)
# Out:
# Model: KNN
# Accuracy: 0.87
# Precision: 0.89
# Recall: 0.85
# F1 Score: 0.87
# Confusion Matrix:
#  [[133  17]
#  [ 24 134]]
# -------------------------
# Model: Logistic Regression
# Accuracy: 0.82
# Precision: 0.78
# Recall: 0.89
# F1 Score: 0.83
# Confusion Matrix:
#  [[111  39]
#  [ 17 141]]
# -------------------------
# Model: SVC
# Accuracy: 0.91
# Precision: 0.91
# Recall: 0.91
# F1 Score: 0.91
# Confusion Matrix:
#  [[136  14]
#  [ 15 143]]
# -------------------------

# %%
def evaluate_recall(model, X_test, y_test):
    y_pred = model.predict(X_test)
    return recall_score(y_test, y_pred)

print("KNN Recall:", evaluate_recall(knn, X_test_scaled, y_test))
print("Logistic Regression Recall:", evaluate_recall(logistic_regression, X_test_scaled, y_test))
print("SVC Recall:", evaluate_recall(svc, X_test_scaled, y_test))
# Out:
# KNN Recall: 0.8481012658227848
# Logistic Regression Recall: 0.8924050632911392
# SVC Recall: 0.9050632911392406

# %%
plt.figure(figsize=(10, 6))

for name, model in models.items():
    if hasattr(model, "predict_proba"):
        y_pred_prob = model.predict_proba(X_test_scaled if name in ["KNN", "Logistic Regression", "SVC"] else X_test)[:, 1]
    else:
        y_pred_prob = model.decision_function(X_test_scaled if name in ["KNN", "Logistic Regression", "SVC"] else X_test)
    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    plt.plot(fpr, tpr, label=f"{name} (AUC: {roc_auc_score(y_test, y_pred_prob):.3f})")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.title("ROC Curve Comparison")
plt.show()

# %%
def plot_model_comparison(models, X_test, X_test_scaled, y_test):
    metrics = {"Accuracy": [], "Precision": [], "Recall": [], "F1 Score": []}
    model_names = []

    for name, model in models.items():
        y_pred = model.predict(X_test_scaled if name in ["KNN", "Logistic Regression", "SVC"] else X_test)
        metrics["Accuracy"].append(accuracy_score(y_test, y_pred))
        metrics["Precision"].append(precision_score(y_test, y_pred))
        metrics["Recall"].append(recall_score(y_test, y_pred))
        metrics["F1 Score"].append(f1_score(y_test, y_pred))
        model_names.append(name)

    metrics_df = pd.DataFrame(metrics, index=model_names)
    metrics_df.plot(kind='bar', figsize=(10, 6))
    plt.title("Model Performance Comparison")
    plt.ylabel("Score")
    plt.xlabel("Models")
    plt.legend(loc="lower right")
    plt.show()

plot_model_comparison(models, X_test, X_test_scaled, y_test)

# %%
import joblib
# Sauvegarder les modèles
joblib.dump(knn, 'knn_model.joblib')
joblib.dump(logistic_regression, 'logistic_regression_model.joblib')
joblib.dump(svc, 'svc_model.joblib')

print("Les modèles ont été sauvegardés avec succès.")
# Out:
# Les modèles ont été sauvegardés avec succès.

# %%
# Étape 1 : Charger le modèle sauvegardé
# Remplacez 'modele_sauvegarde.joblib' par le chemin de votre modèle sauvegardé
modele_path = 'knn_model.joblib'
modele = joblib.load(modele_path)

# Étape 2 : Créer les données d'exemple
# Exemple : [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]
donnees_exemple = np.array([[52, 1, 0, 125, 212, 0, 1, 168, 0, 1, 2, 2, 3]])

# Étape 3 : Effectuer une prédiction
# Assurez-vous que le modèle a été entraîné sur des données normalisées/scalées si nécessaire.
prediction = modele.predict(donnees_exemple)

# Étape 4 : Afficher le résultat
print("Données d'exemple :", donnees_exemple)
print("Prédiction (target) :", prediction[0])
# Out:
# Données d'exemple : [[ 52   1   0 125 212   0   1 168   0   1   2   2   3]]
# Prédiction (target) : 0

# %%
# Étape 1 : Charger le modèle sauvegardé
# Remplacez 'modele_sauvegarde.joblib' par le chemin de votre modèle sauvegardé
modele_path = 'logistic_regression_model.joblib'
modele = joblib.load(modele_path)

# Étape 2 : Créer les données d'exemple
# Exemple : [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]
donnees_exemple = np.array([[52, 1, 0, 125, 212, 0, 1, 168, 0, 1, 2, 2, 3]])

# Étape 3 : Effectuer une prédiction
# Assurez-vous que le modèle a été entraîné sur des données normalisées/scalées si nécessaire.
prediction = modele.predict(donnees_exemple)

# Étape 4 : Afficher le résultat
print("Données d'exemple :", donnees_exemple)
print("Prédiction (target) :", prediction[0])
# Out:
# Données d'exemple : [[ 52   1   0 125 212   0   1 168   0   1   2   2   3]]
# Prédiction (target) : 0

# %%
# Étape 1 : Charger le modèle sauvegardé
# Remplacez 'modele_sauvegarde.joblib' par le chemin de votre modèle sauvegardé
modele_path = 'svc_model.joblib'
modele = joblib.load(modele_path)

# Étape 2 : Créer les données d'exemple
# Exemple : [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]
donnees_exemple = np.array([[52, 1, 0, 125, 212, 0, 1, 168, 0, 1, 2, 2, 3]])

# Étape 3 : Effectuer une prédiction
# Assurez-vous que le modèle a été entraîné sur des données normalisées/scalées si nécessaire.
prediction = modele.predict(donnees_exemple)

# Étape 4 : Afficher le résultat
print("Données d'exemple :", donnees_exemple)
print("Prédiction (target) :", prediction[0])
# Out:
# Données d'exemple : [[ 52   1   0 125 212   0   1 168   0   1   2   2   3]]
# Prédiction (target) : 1

# %%
modele_path = 'logistic_regression_model.joblib'
modele = joblib.load(modele_path)

# Étape 2 : Créer plusieurs exemples de données
# Chaque ligne représente un exemple : [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]
donnees_exemples = np.array([
    [52, 1, 0, 125, 212, 0, 1, 168, 0, 1, 2, 2, 3],  # Exemple 1
    [61, 0, 2, 145, 233, 1, 0, 150, 1, 2.3, 1, 0, 2],  # Exemple 2
    [45, 1, 1, 130, 205, 0, 1, 172, 0, 0.6, 2, 1, 3],  # Exemple 3
    [54, 1, 2, 120, 260, 0, 0, 160, 1, 1.5, 0, 0, 2],  # Exemple 4
    [59, 0, 3, 135, 270, 1, 1, 145, 0, 0.8, 1, 1, 3]   # Exemple 5
])

# Étape 3 : Effectuer des prédictions pour tous les exemples
# Assurez-vous que le modèle est compatible avec le format des données
predictions = modele.predict(donnees_exemples)

# Étape 4 : Afficher les résultats
print("Données d'exemples et prédictions correspondantes :\n")
for i, exemple in enumerate(donnees_exemples):
    print(f"Exemple {i+1} : {exemple}")
    print(f"Prédiction (target) : {predictions[i]}")
    print("-" * 50)
# Out:
# Données d'exemples et prédictions correspondantes :
#
# Exemple 1 : [ 52.   1.   0. 125. 212.   0.   1. 168.   0.   1.   2.   2.   3.]
# Prédiction (target) : 0
# --------------------------------------------------
# Exemple 2 : [ 61.    0.    2.  145.  233.    1.    0.  150.    1.    2.3   1.    0.
#    2. ]
# Prédiction (target) : 0
# --------------------------------------------------
# Exemple 3 : [ 45.    1.    1.  130.  205.    0.    1.  172.    0.    0.6   2.    1.
#    3. ]
# Prédiction (target) : 0
# --------------------------------------------------
# Exemple 4 : [ 54.    1.    2.  120.  260.    0.    0.  160.    1.    1.5   0.    0.
#    2. ]
# Prédiction (target) : 0
# --------------------------------------------------
# Exemple 5 : [ 59.    0.    3.  135.  270.    1.    1.  145.    0.    0.8   1.    1.
#    3. ]
# Prédiction (target) : 0
# --------------------------------------------------
